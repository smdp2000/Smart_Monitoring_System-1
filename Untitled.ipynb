# %%
import cv2
import numpy as np
import dlib
import matplotlib.pyplot as plt
import pandas as pd
df = pd.DataFrame()
cap = cv2.VideoCapture(0)
# l=[]
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")
# _, frame = cap.read()
# gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

# faces = detector(gray)

# for face in faces:
#     x1 = face.left()
#     y1 = face.top()
#     x2 = face.right()
#     y2 = face.bottom()
#     cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 3)
    
#     landmarks = predictor(gray, face)
#     for n in range(0,68):
#         x = landmarks.part(n).x
#         y = landmarks.part(n).y
#         l.append([x,y])
#         print (x,y)
        #mylist = [1,2,3]

# %%
for i in range(500):
    _, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = detector(gray)
    for face in faces:
        x1 = face.left()
        y1 = face.top()
        x2 = face.right()
        y2 = face.bottom()
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 3)

        landmarks = predictor(gray, face)
        xc = []
        yc = []
        for n in range(0, 68):
            x = landmarks.part(n).x
            y = landmarks.part(n).y
            xc.append(x)
            yc.append(y)
            cv2.circle(frame, (x, y), 4, (255, 0, 0), -1)
            
            #diff = 
            #cv2.line(frame,(l[n][0],l[n][1]),(x,y), (0,0,255), 4)
    
    df['x'+str(i)] = xc
    df['y'+str(i)] = yc
    
    cv2.imshow("Frame", frame)
    #plt.plot(l)
    

    key = cv2.waitKey(1)
    if key == 27:
        break
        
cap.release ()
cv2.destroyAllWindows ()

# %%
df
# Out:
#      x0   y0   x1   y1   x2   y2   x3   y3   x4   y4  ...   x495  y495  x496  \
# 0   193   42  195   35  202   26  200   28  198   24  ...    220    57   218
# 1   193   71  194   63  200   54  198   56  196   53  ...    215    84   214
# 2   195  102  196   93  199   81  198   84  197   81  ...    213   112   211
# 3   201  130  200  122  203  107  203  111  202  108  ...    215   139   213
# 4   211  158  210  150  211  132  212  135  210  133  ...    225   163   222
# 5   226  185  225  177  223  155  225  159  224  157  ...    240   184   236
# 6   244  209  243  201  239  176  243  179  241  178  ...    258   203   253
# 7   268  228  267  221  260  193  263  195  262  195  ...    278   219   273
# 8   294  234  292  228  285  199  288  201  287  201  ...    300   225   294
# 9   318  230  316  226  309  198  311  198  311  199  ...    318   223   312
# 10  340  214  337  210  330  185  331  185  331  185  ...    331   209   327
# 11  356  191  353  189  347  168  349  168  348  168  ...    341   191   339
# 12  369  167  367  166  361  148  363  148  362  148  ...    353   175   351
# 13  377  141  376  140  372  126  374  126  374  126  ...    363   157   361
# 14  382  115  382  114  381  104  383  104  383  103  ...    373   139   371
# 15  386   90  387   88  389   81  391   80  391   80  ...    380   121   378
# 16  388   65  389   63  394   57  395   55  396   55  ...    383   103   382
# 17  219   32  221   31  225   22  224   24  223   22  ...    260    60   255
# 18  235   19  238   19  241   12  241   14  240   13  ...    279    55   274
# 19  258   16  261   18  264   14  263   15  262   14  ...    300    58   295
# 20  280   24  283   26  284   22  283   23  283   22  ...    318    67   314
# 3    136   210   135   206   135   193   149
# 4    160   218   159   214   159   198   177
# 5    181   232   181   228   181   207   205
# 6    200   250   200   243   201   221   230
# 7    216   269   216   262   218   241   249
# 8    222   291   221   282   226   266   258
# 9    220   309   220   301   226   290   259
# 10   207   325   208   317   213   312   248
# 11   191   339   193   331   199   330   233
# 12   175   351   177   345   183   345   213
# 13   157   362   159   357   164   358   191
# 14   140   371   141   367   145   366   168
# 15   121   378   122   375   125   373   145
# 16   102   382   103   380   105   377   123
# 17    59   251    56   241    56   239    58
# 18    53   270    51   260    49   254    49
# 19    56   290    54   282    52   274    50
# 20    66   308    64   301    62   293    60
# 21    80   323    78   316    76   308    73
# 22    86   340    85   333    84   327    81
# 23    82   354    81   348    80   342    78
# 24    80   368    79   364    79   358    78
# 25    82   381    82   378    83   371    82
# 26    92   386    93   384    95   376    96
# 27    98   328    96   321    93   313    92
# 28   114   326   112   319   109   310   106
# 29   129   325   127   317   125   307   120
# ..   ...   ...   ...   ...   ...   ...   ...
# 38    81   290    79   284    76   275    80
# 39    90   299    88   293    85   284    88
# 40    90   287    88   281    85   273    87
# 41    87   276    85   269    82   263    84
# 42   101   341   100   335    98   329    99
# 43    97   351    96   347    94   340    96
# 44    99   361    98   357    97   349    99
# 45   104   368   104   364   104   356   106
# 46   107   360   106   355   106   347   106
# 47   105   350   104   344   103   338   103
# 48   167   272   165   265   163   254   179
# 49   168   288   166   281   164   268   175
# 50   169   303   167   296   166   282   175
# 51   173   310   171   303   170   291   179
# 52   172   318   170   311   170   301   179
# 53   176   325   174   318   174   311   185
# 54   180   330   179   325   180   318   196
# 55   190   320   189   313   190   306   206
# 56   192   312   191   304   190   295   208
# 57   191   303   190   296   188   284   207
# 58   189   295   188   287   185   274   204
# 59   182   283   180   276   178   263   195
# 60   169   278   167   270   165   259   180
# 61   176   301   174   294   172   280   184
# 62   178   309   177   301   175   289   187
# 63   179   316   178   309   176   299   188
# 64   180   326   179   320   179   313   194
# 65   180   315   178   307   178   298   194
# 66   180   307   177   299   177   288   193
# 67   178   299   175   291   174   278   190
#
# [68 rows x 1000 columns]

# %%
ntx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-02777dd08ad9> in <module>()
# ----> 1 ntx
#
# NameError: name 'ntx' is not defined

# %%
var

# %%
nt = df.values [33].tolist()
ntx = nt [0::2]
ntx.sort()

# %%
from scipy.stats import norm

# %%
mean = np.mean (ntx)
sd = np.std (ntx)

plt.plot (ntx, norm.pdf (ntx, mean, sd))

# %%
plot

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df = pd.DataFrame(l)

# %%
df.columns = ['x','y']

# %%
plt.plot(df['x'],df['y'])

# %%
plt.scatter(df['x'],df['y'])
plt.plot(df['x'],df['y'])

# %%
l

# %%
l

# %%
df

# %%
df

# %%
df

# %%
df
